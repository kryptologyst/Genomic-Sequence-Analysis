# %% [markdown]
# # Genomic Sequence Analysis Demo
#
# This notebook demonstrates the genomic sequence analysis toolkit for promoter vs non-promoter classification.
#
# ## ⚠️ Disclaimer
# **This is a research demonstration tool only. Not for clinical use.**

# %%
# Import required libraries
import sys
sys.path.append('.')

import torch
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

from src.utils.core import Config, set_seed, get_device
from src.data import GenomicSequenceEncoder, generate_synthetic_data, create_data_loaders
from src.models import create_model
from src.train import ModelTrainer
from src.metrics import ModelEvaluator

# Set random seed for reproducibility
set_seed(42)

# Get device
device = get_device()
print(f"Using device: {device}")
